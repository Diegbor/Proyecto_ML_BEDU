# %% [markdown]
# <a href="https://colab.research.google.com/github/Diegbor/Proyecto_ML_BEDU/blob/main/Proyecto_ML_Equipo_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# !wget https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/?select=creditcard.csv
# Out:
# --2023-11-29 00:39:08--  https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud/?select=creditcard.csv
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?select=creditcard.csv’
#
# index.html?select=c     [ <=>                ]  14.73K  --.-KB/s    in 0s
#
# 2023-11-29 00:39:08 (65.4 MB/s) - ‘index.html?select=creditcard.csv’ saved [15083]

# %%
import pandas
df = pandas.read_csv("/content/creditcard.csv")
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 45641  42436 -2.481639 -2.439949  0.363642  1.216827  2.572442 -1.264220
# 45642  42436  1.223475  0.014944  0.471312 -0.038410 -0.566793 -0.867970
# 45643  42436  1.258657  0.421016  0.325437  0.684259 -0.292529 -1.052786
# 45644  42437 -0.500147  1.000770  1.809639 -0.114551  0.333865 -0.577076
# 45645  42437 -0.652459  0.177290  1.955607 -1.879724 -0.368457       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...
